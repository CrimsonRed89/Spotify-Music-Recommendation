# %% [markdown]
# <a href="https://colab.research.google.com/github/CrimsonRed89/Spotify-Music-Recommendation/blob/main/spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
import matplotlib
import seaborn as sb
# %matplotlib inline
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = df=pd.read_csv("/content/drive/Othercomputers/My PC/Coding/python/Projects/Spotify Music Reccomendation/spotify_millsongdata.csv")
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.describe()
# Out:
#               artist                                    song  \
# count          57650                                   57650
# unique           643                                   44824
# top     Donna Summer  Have Yourself A Merry Little Christmas
# freq             191                                      35
#
#                                               link  \
# count                                        57650
# unique                                       57650
# top     /a/abba/ahes+my+kind+of+girl_20598417.html
# freq                                             1
#
#                                                      text
# count                                               57650
# unique                                              57494
# top     I just came back from a lovely trip along the ...
# freq                                                    6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  object
#  1   song    57650 non-null  object
#  2   link    57650 non-null  object
#  3   text    57650 non-null  object
# dtypes: object(4)
# memory usage: 1.8+ MB

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isna().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df =df.sample(10000).drop('link', axis=1).reset_index(drop=True)
df.head()
# Out:
#           artist                    song  \
# 0     Eurythmics   I've Tried Everything
# 1    Patti Smith           Ask The Angel
# 2  Willie Nelson            Family Bible
# 3        Madonna         Little Boy Lost
# 4    Nina Simone  Papa, Can You Hear Me?
#
#                                                 text
# 0  The truth of life is the greatest gift  \r\nBu...
# 1  Moooooove! Ask the angels who they're calling,...
# 2  There's a family Bible on the table  \r\nEach ...
# 3  He runs through the street  \r\nCause his hous...
# 4  Papa, can you hear me?  \r\nPapa, can you see ...

# %%
df['text'][0]
# Out:
# "The truth of life is the greatest gift  \r\nBut I don't think I can make it fit  \r\nAnd who would guess it would come to this  \r\nWhen I've tried everything  \r\n  \r\nAnd I should know but I can't explain  \r\nThe endless noise sounding in my brain  \r\nWho would've thought that you could feel such pain  \r\nWhen you've tried everything  \r\n  \r\nYea, you're a loser now  \r\nYea, you're a loser now  \r\n  \r\nI should be cool  \r\nBut I'm burning hot  \r\nI should be good  \r\nBut I fell apart  \r\nDon't look at me now don't even start  \r\nCause I've tried everything  \r\n  \r\nYea, you're a loser now  \r\nYea, you're a loser now\r\n\r\n"

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)
df['text']
# Out:
# 0       the truth of life is the greatest gift  \r but...
# 1       moooooove! ask the angels who they're calling,...
# 2       there's a family bible on the table  \r each p...
# 3       he runs through the street  \r cause his house...
# 4       papa, can you hear me?  \r papa, can you see m...
#                               ...
# 9995    going back to the memories  \r reminiscing bou...
# 9996    donna has a nine year old kid  \r in another m...
# 9997    when you're in a dream,  \r and you think you'...
# 9998    she was given the world  \r so much that she c...
# 9999    (land of stardust land of glamour)  \r   \r (h...
# Name: text, Length: 10000, dtype: object

# %%
import nltk
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
nltk.download('punkt')

def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['text'] = df['text'].apply(lambda x: tokenization(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidv = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidv.fit_transform(df['text'])
similarity = cosine_similarity(matrix)

# %%
similarity[0]
# Out:
# array([1.        , 0.0078746 , 0.00212766, ..., 0.06899119, 0.0341307 ,
#        0.00403127])

# %%
df.head()
# Out:
#           artist                    song  \
# 0     Eurythmics   I've Tried Everything
# 1    Patti Smith           Ask The Angel
# 2  Willie Nelson            Family Bible
# 3        Madonna         Little Boy Lost
# 4    Nina Simone  Papa, Can You Hear Me?
#
#                                                 text
# 0  the truth of life is the greatest gift but i d...
# 1  moooooov ! ask the angel who they 're call , g...
# 2  there 's a famili bibl on the tabl each page i...
# 3  he run through the street caus hi hous 's fall...
# 4  papa , can you hear me ? papa , can you see me...

# %%
def recommendation(song_df):
    idx = df[df['song'] == song_df].index[0]
    distances = sorted(list(enumerate(similarity[idx])),reverse=True,key=lambda x:x[1])

    songs = []
    for m_id in distances[1:21]:
        songs.append(df.iloc[m_id[0]].song)

    return songs

# %%
recommendation('Ask The Angel')
# Out:
# ['Wild Wild Water',
#  'Wild Ones',
#  'Wild Again',
#  'Call Of The Wild',
#  'Something Wild',
#  'Wild Life',
#  'Young Girls',
#  'Born To Be Wild',
#  'Bad Boys Running Wild',
#  'Salvation Jane',
#  'Life Is Wild',
#  'Let Him Run Wild',
#  'Never Saga',
#  "I'll Be Around",
#  "I'd Lie For You",
#  'Wild Child',
#  'Charlie Brown',
#  'Get Up And Go',
#  'The Night Is Yours, The Night Is Mine',
#  'Wild Child']
